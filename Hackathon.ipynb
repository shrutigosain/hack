# %%
print('country name \nPopulation \nLanguages spoken \nGender distribution \nUnemployment \ntype of community \ntype of govt \nRejection and Acceptance rate \nHuman development index \nEducation \nEconomycost of living \nPersonal freedomprogressive \nCrime stat')
# Out:
# country name
# Population
# Languages spoken
# Gender distribution
# Unemployment
# type of community
# type of govt
# Rejection and Acceptance rate
# Human development index
# Education
# Economycost of living
# Personal freedomprogressive
# Crime stat

# %%
import pandas as pd

# %%
csv1=pd.read_csv('hackATHON/asylum_seekers_monthly.csv', dtype='unicode')
csv1 = csv1.rename(columns={'Country / territory of asylum/residence': 'destination_country'})
csv1['destination_country']=csv1['destination_country'].replace({'USA (INS/DHS)': 'United States'})
csv1['destination_country']=csv1['destination_country'].replace({'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom'})
# Out:
#        destination_country       Origin   Year     Month Value
# 0                Australia  Afghanistan  False   January     8
# 1                Australia  Afghanistan  False  February    10
# 2                Australia  Afghanistan  False     March    25
# 3                Australia  Afghanistan  False     April    25
# 4                Australia  Afghanistan  False       May     7
# ...                    ...          ...    ...       ...   ...
# 332184       United States     Zimbabwe  False  December    28
# 332185       United States     Zimbabwe  False  February    27
# 332186       United States     Zimbabwe  False     March    42
# 332187       United States     Zimbabwe  False     April    16
# 332188       United States     Zimbabwe  False       May    12
#
# [332189 rows x 5 columns]

# %%
my_list =['United States', 'Germany','Canada', 'United Kingdom','France','Australia','Saudi Arabia','Spain','Italy','Switzerland','Japan','United Arab Emirates','Singapore','South Africa','Sweden','Russia','New Zealand','China','Netherlands','Brazil','Turkey','South Korea']

# %%
df=csv1[csv1['destination_country'].isin(my_list)]

# %%
df
# Out:
#        destination_country       Origin  Year     Month Value
# 0                Australia  Afghanistan  1999   January     8
# 1                Australia  Afghanistan  1999  February    10
# 2                Australia  Afghanistan  1999     March    25
# 3                Australia  Afghanistan  1999     April    25
# 4                Australia  Afghanistan  1999       May     7
# ...                    ...          ...   ...       ...   ...
# 332184       United States     Zimbabwe  2016  December    28
# 332185       United States     Zimbabwe  2017  February    27
# 332186       United States     Zimbabwe  2017     March    42
# 332187       United States     Zimbabwe  2017     April    16
# 332188       United States     Zimbabwe  2017       May    12
#
# [185926 rows x 5 columns]

# %%
csv2=pd.read_csv('hackATHON/asylum_seekers.csv', dtype='unicode')
csv2['Country / territory of asylum/residence']=csv2['Country / territory of asylum/residence'].replace({'United States of America': 'United States'})
csv2 = csv2.rename(columns={'Country / territory of asylum/residence': 'destination_country'})
csv2
# Out:
#         Year destination_country       Origin RSD procedure type / level  \
# 0       2000            Zimbabwe  Afghanistan                     G / FI
# 1       2000        South Africa  Afghanistan                     G / FI
# 2       2000          Uzbekistan  Afghanistan                     U / FI
# 3       2000       United States  Afghanistan                     G / EO
# 4       2000       United States  Afghanistan                     G / IN
# ...      ...                 ...          ...                        ...
# 129715  2016       United States     Zimbabwe                     G / IN
# 129716  2016       United States     Zimbabwe                     G / EO
# 129717  2016        South Africa     Zimbabwe                     G / AR
# 129718  2016        South Africa     Zimbabwe                     G / FI
# 129719  2016              Zambia     Zimbabwe                     G / FI
#
#        Tota pending start-year of which UNHCR-assisted(start-year)  \
# ...

# %%
df2=csv2[csv2['destination_country'].isin(my_list)]
df2
# Out:
#         Year destination_country       Origin RSD procedure type / level  \
# 1       2000        South Africa  Afghanistan                     G / FI
# 3       2000       United States  Afghanistan                     G / EO
# 4       2000       United States  Afghanistan                     G / IN
# 6       2000              Turkey  Afghanistan                     U / FI
# 12      2000              Sweden  Afghanistan                     G / AR
# ...      ...                 ...          ...                        ...
# 129713  2016              Turkey     Zimbabwe                     U / FI
# 129715  2016       United States     Zimbabwe                     G / IN
# 129716  2016       United States     Zimbabwe                     G / EO
# 129717  2016        South Africa     Zimbabwe                     G / AR
# 129718  2016        South Africa     Zimbabwe                     G / FI
#
#        Tota pending start-year of which UNHCR-assisted(start-year)  \
# ...

# %%
csv3=pd.read_csv('hackATHON/demographics.csv', dtype='unicode')
csv3['Country / territory of asylum/residence']=csv2['Country / territory of asylum/residence'].replace({'United States of America': 'United States'})
csv2 = csv2.rename(columns={'Country / territory of asylum/residence': 'destination_country'})
csv2
# Out:
#        Year Country / territory of asylum/residence  \
# 0      2001                             Afghanistan
# 1      2001                             Afghanistan
# 2      2001                             Afghanistan
# 3      2001                                  Angola
# 4      2001                                  Angola
# ...     ...                                     ...
# 18351  2016                                  Zambia
# 18352  2016                                  Zambia
# 18353  2016                                  Zambia
# 18354  2016                                Zimbabwe
# 18355  2016                                Zimbabwe
#
#                                        Location Name Female 0-4 Female 5-11  \
# 0                                              Kabul          0         NaN
# 1                                            Various      14335         NaN
# 2                                              Herat          0         NaN
# ...

# %%
csv4=pd.read_csv('hackATHON/persons_of_concern.csv', dtype='unicode')
csv4
# Out:
#         Year Country / territory of asylum/residence            Origin  \
# 0       1951                               Australia   Various/Unknown
# 1       1951                                 Austria   Various/Unknown
# 2       1951                                 Belgium   Various/Unknown
# 3       1951                                  Canada   Various/Unknown
# 4       1951                             Switzerland   Various/Unknown
# ...      ...                                     ...               ...
# 117316  2016                                Zimbabwe           Somalia
# 117317  2016                                Zimbabwe  Syrian Arab Rep.
# 117318  2016                                Zimbabwe            Uganda
# 117319  2016                                Zimbabwe      South Africa
# 117320  2016                                Zimbabwe          Zimbabwe
#
#        Refugees (incl. refugee-like situations)  \
# 0                                        180000
# ...

# %%
csv5=pd.read_csv('hackATHON/resettlement.csv', dtype='unicode')
csv5
# Out:
#      Country / territory of asylum/residence      Origin  Year Value
# 0                                     Canada     Albania  1959    17
# 1                                     Canada     Austria  1959    17
# 2                                     Canada     Belgium  1959     2
# 3                                     Canada    Bulgaria  1959    35
# 4                                     Canada       China  1959     2
# ...                                      ...         ...   ...   ...
# 9070                United States of America  Uzbekistan  2016    46
# 9071                United States of America    Viet Nam  2016    57
# 9072                United States of America       Yemen  2016    27
# 9073                United States of America      Zambia  2016     *
# 9074                United States of America    Zimbabwe  2016    11
#
# [9075 rows x 4 columns]

# %%
csv6=pd.read_csv('hackATHON/time_series.csv', dtype='unicode')
csv6
# Out:
#         Year Country / territory of asylum/residence           Origin  \
# 0       1951                               Australia  Various/Unknown
# 1       1951                                 Austria  Various/Unknown
# 2       1951                                 Belgium  Various/Unknown
# 3       1951                                  Canada  Various/Unknown
# 4       1951                             Switzerland  Various/Unknown
# ...      ...                                     ...              ...
# 298436  2016                                Zimbabwe         Zimbabwe
# 298437  2016                                Zimbabwe         Zimbabwe
# 298438  2016                                Zimbabwe         Zimbabwe
# 298439  2016                                Zimbabwe         Zimbabwe
# 298440  2016                                Zimbabwe         Zimbabwe
#
#                                  Population type   Value
# 0       Refugees (incl. refugee-like situations)  180000
# ...

# %%
csv7=pd.read_csv('hackATHON/Costofliving.csv', dtype='unicode')
csv8=pd.read_csv('hackATHON/govt.csv', dtype='unicode')
csv9=pd.read_csv('hackATHON/crimeindex.csv', dtype='unicode')
csv10=pd.read_csv('hackATHON/population.csv', dtype='unicode')

# %%
csv10
# Out:
#        Country Name  Year     Count
# 0             Aruba  1960     54211
# 1       Afghanistan  1960   8996973
# 2            Angola  1960   5454933
# 3           Albania  1960   1608800
# 4           Andorra  1960     13411
# ...             ...   ...       ...
# 12590        Kosovo  2017   1830700
# 12591   Yemen, Rep.  2017  27834821
# 12592  South Africa  2017  57000451
# 12593        Zambia  2017  16853688
# 12594      Zimbabwe  2017  14236745
#
# [12595 rows x 3 columns]
