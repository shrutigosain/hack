# %%
print('country name \nPopulation \nLanguages spoken \nGender distribution \nUnemployment \ntype of community \ntype of govt \nRejection and Acceptance rate \nHuman development index \nEducation \nEconomycost of living \nPersonal freedomprogressive \nCrime stat')
# Out:
# country name
# Population
# Languages spoken
# Gender distribution
# Unemployment
# type of community
# type of govt
# Rejection and Acceptance rate
# Human development index
# Education
# Economycost of living
# Personal freedomprogressive
# Crime stat

# %%
import pandas as pd

# %%
csv1=pd.read_csv('hackATHON/asylum_seekers_monthly.csv', dtype='unicode')
csv1 = csv1.rename(columns={'Country / territory of asylum/residence': 'destination_country'})
csv1['destination_country']=csv1['destination_country'].replace({'USA (INS/DHS)': 'United States'})
csv1['destination_country']=csv1['destination_country'].replace({'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom'})
csv1
# Out:
#        destination_country       Origin  Year     Month Value
# 0                Australia  Afghanistan  1999   January     8
# 1                Australia  Afghanistan  1999  February    10
# 2                Australia  Afghanistan  1999     March    25
# 3                Australia  Afghanistan  1999     April    25
# 4                Australia  Afghanistan  1999       May     7
# ...                    ...          ...   ...       ...   ...
# 332184       United States     Zimbabwe  2016  December    28
# 332185       United States     Zimbabwe  2017  February    27
# 332186       United States     Zimbabwe  2017     March    42
# 332187       United States     Zimbabwe  2017     April    16
# 332188       United States     Zimbabwe  2017       May    12
#
# [332189 rows x 5 columns]

# %%
my_list =['United States', 'Germany','Canada', 'United Kingdom','France','Australia','Saudi Arabia','Spain','Italy','Switzerland','Japan','United Arab Emirates','Singapore','South Africa','Sweden','Russia','New Zealand','China','Netherlands','Brazil','Turkey','South Korea'] 


date=['2017']
dff=csv1[csv1['Year'].isin(date)]
dff
# Out:
#        destination_country       Origin  Year     Month Value
# 305907             Albania  Afghanistan  2017   January    21
# 305908             Albania  Afghanistan  2017  February     *
# 305909             Albania   Bangladesh  2017   January     *
# 305910             Albania      Croatia  2017  February     *
# 305913             Albania     Ethiopia  2017     March     *
# ...                    ...          ...   ...       ...   ...
# 332172       United States       Zambia  2017     April     *
# 332185       United States     Zimbabwe  2017  February    27
# 332186       United States     Zimbabwe  2017     March    42
# 332187       United States     Zimbabwe  2017     April    16
# 332188       United States     Zimbabwe  2017       May    12
#
# [7179 rows x 5 columns]

# %%
df=dff[dff['destination_country'].isin(my_list)]
df
# Out:
#        destination_country       Origin  Year     Month Value
# 305962           Australia  Afghanistan  2017   January   186
# 305963           Australia  Afghanistan  2017  February   239
# 305964           Australia  Afghanistan  2017     March   270
# 305965           Australia  Afghanistan  2017     April   165
# 305966           Australia  Afghanistan  2017       May   142
# ...                    ...          ...   ...       ...   ...
# 332172       United States       Zambia  2017     April     *
# 332185       United States     Zimbabwe  2017  February    27
# 332186       United States     Zimbabwe  2017     March    42
# 332187       United States     Zimbabwe  2017     April    16
# 332188       United States     Zimbabwe  2017       May    12
#
# [4573 rows x 5 columns]

# %%
df
df.to_csv('df')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 2
#       1 df
# ----> 2 df.to_csv('df')
#
# AttributeError: 'function' object has no attribute 'to_csv'

# %%
#df= df.groupby('destination_country')

# %%
df
# Out:
#        destination_country       Origin  Year     Month Value
# 305907             Albania  Afghanistan  2017   January    21
# 305908             Albania  Afghanistan  2017  February     *
# 305909             Albania   Bangladesh  2017   January     *
# 305910             Albania      Croatia  2017  February     *
# 305913             Albania     Ethiopia  2017     March     *
# ...                    ...          ...   ...       ...   ...
# 332172       United States       Zambia  2017     April     *
# 332185       United States     Zimbabwe  2017  February    27
# 332186       United States     Zimbabwe  2017     March    42
# 332187       United States     Zimbabwe  2017     April    16
# 332188       United States     Zimbabwe  2017       May    12
#
# [7179 rows x 5 columns]

# %%
##df2

# %%
csv2=pd.read_csv('hackATHON/asylum_seekers.csv', dtype='unicode')
csv2
# Out:
#         Year Country / territory of asylum/residence       Origin  \
# 0       2000                                Zimbabwe  Afghanistan
# 1       2000                            South Africa  Afghanistan
# 2       2000                              Uzbekistan  Afghanistan
# 3       2000                United States of America  Afghanistan
# 4       2000                United States of America  Afghanistan
# ...      ...                                     ...          ...
# 129715  2016                United States of America     Zimbabwe
# 129716  2016                United States of America     Zimbabwe
# 129717  2016                            South Africa     Zimbabwe
# 129718  2016                            South Africa     Zimbabwe
# 129719  2016                                  Zambia     Zimbabwe
#
#        RSD procedure type / level Tota pending start-year  \
# 0                          G / FI                       0
# 1                          G / FI                       8
# 2                          U / FI                     265
# 3                          G / EO                     196
# 4                          G / IN                     193
# ...                           ...                     ...
# 129715                     G / IN                     232
# 129716                     G / EO                     142
# 129717                     G / AR                      94
# 129718                     G / FI                   41238
# 129719                     G / FI                       *
#
#        of which UNHCR-assisted(start-year) Applied during year  \
# 0                                        0                   5
# 1                                        1                   0
# 2                                      265                2156
# 3                                        0                 225
# 4                                        0                 218
# ...                                    ...                 ...
# 129715                                 NaN                 229
# 129716                                 NaN                  12
# 129717                                   9                 NaN
# 129718                                4124                7964
# 129719                                   *                   *
#
#        decisions_recognized decisions_other Rejected Otherwise closed  \
# 0                         5               0        0                0
# 1                         0               0        0                0
# 2                       747               0      112              327
# 3                       151               0       31               68
# 4                       182               0       51               40
# ...                     ...             ...      ...              ...
# 129715                   16             NaN        *               10
# 129716                    *             NaN        *               23
# 129717                  NaN             NaN      NaN               94
# 129718                   73             NaN     7869              NaN
# 129719                    0             NaN        *                *
#
#        Total decisions Total pending end-year  \
# 0                    5                      0
# 1                  NaN                      8
# 2                 1186                   1235
# 3                  250                    171
# 4                  273                    150
# ...                ...                    ...
# 129715              28                    435
# 129716              31                    138
# 129717              94                      0
# 129718            7942                  41260
# 129719               *                      *
#
#        of which UNHCR-assisted(end-year)
# 0                                      0
# 1                                      0
# 2                                   1235
# 3                                      0
# 4                                      0
# ...                                  ...
# 129715                               NaN
# 129716                               NaN
# 129717                               NaN
# 129718                               NaN
# 129719                                 *
#
# [129720 rows x 14 columns]

# %%
csv2 = csv2.rename(columns={'Country / territory of asylum/residence': 'destination_country'})
csv2['destination_country']=csv2['destination_country'].replace({'USA (INS/DHS)': 'United States'})
csv2['destination_country']=csv2['destination_country'].replace({'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom'})
csv2
# Out:
#         Year       destination_country       Origin  \
# 0       2000                  Zimbabwe  Afghanistan
# 1       2000              South Africa  Afghanistan
# 2       2000                Uzbekistan  Afghanistan
# 3       2000  United States of America  Afghanistan
# 4       2000  United States of America  Afghanistan
# ...      ...                       ...          ...
# 129715  2016  United States of America     Zimbabwe
# 129716  2016  United States of America     Zimbabwe
# 129717  2016              South Africa     Zimbabwe
# 129718  2016              South Africa     Zimbabwe
# 129719  2016                    Zambia     Zimbabwe
#
#        RSD procedure type / level Tota pending start-year  \
# 0                          G / FI                       0
# 1                          G / FI                       8
# 2                          U / FI                     265
# 3                          G / EO                     196
# 4                          G / IN                     193
# ...                           ...                     ...
# 129715                     G / IN                     232
# 129716                     G / EO                     142
# 129717                     G / AR                      94
# 129718                     G / FI                   41238
# 129719                     G / FI                       *
#
#        of which UNHCR-assisted(start-year) Applied during year  \
# 0                                        0                   5
# 1                                        1                   0
# 2                                      265                2156
# 3                                        0                 225
# 4                                        0                 218
# ...                                    ...                 ...
# 129715                                 NaN                 229
# 129716                                 NaN                  12
# 129717                                   9                 NaN
# 129718                                4124                7964
# 129719                                   *                   *
#
#        decisions_recognized decisions_other Rejected Otherwise closed  \
# 0                         5               0        0                0
# 1                         0               0        0                0
# 2                       747               0      112              327
# 3                       151               0       31               68
# 4                       182               0       51               40
# ...                     ...             ...      ...              ...
# 129715                   16             NaN        *               10
# 129716                    *             NaN        *               23
# 129717                  NaN             NaN      NaN               94
# 129718                   73             NaN     7869              NaN
# 129719                    0             NaN        *                *
#
#        Total decisions Total pending end-year  \
# 0                    5                      0
# 1                  NaN                      8
# 2                 1186                   1235
# 3                  250                    171
# 4                  273                    150
# ...                ...                    ...
# 129715              28                    435
# 129716              31                    138
# 129717              94                      0
# 129718            7942                  41260
# 129719               *                      *
#
#        of which UNHCR-assisted(end-year)
# 0                                      0
# 1                                      0
# 2                                   1235
# 3                                      0
# 4                                      0
# ...                                  ...
# 129715                               NaN
# 129716                               NaN
# 129717                               NaN
# 129718                               NaN
# 129719                                 *
#
# [129720 rows x 14 columns]

# %%
df2=csv2[csv2['destination_country'].isin(my_list)]
date1=['2016']
df2=csv2[csv2['Year'].isin(date1)]

df2=df2.drop(['Total pending end-year','of which UNHCR-assisted(end-year)','decisions_recognized','RSD procedure type / level','Tota pending start-year','of which UNHCR-assisted(start-year)','Applied during year','decisions_other','Otherwise closed','Otherwise closed'],axis=1)
df2
# Out:
#         Year       destination_country       Origin Rejected Total decisions
# 119259  2016            United Kingdom        Aruba      NaN             NaN
# 119260  2016            United Kingdom        Aruba        0             NaN
# 119261  2016            United Kingdom        Aruba        0             NaN
# 119262  2016                    Angola  Afghanistan      NaN             NaN
# 119263  2016                   Albania  Afghanistan      NaN              64
# ...      ...                       ...          ...      ...             ...
# 129715  2016  United States of America     Zimbabwe        *              28
# 129716  2016  United States of America     Zimbabwe        *              31
# 129717  2016              South Africa     Zimbabwe      NaN              94
# 129718  2016              South Africa     Zimbabwe     7869            7942
# 129719  2016                    Zambia     Zimbabwe        *               *
#
# [10461 rows x 5 columns]

# %%
csv3=pd.read_csv('hackATHON/demographics.csv', dtype='unicode')
csv3 = csv3.rename(columns={'Country / territory of asylum/residence': 'destination_country'})
csv3['destination_country']=csv3['destination_country'].replace({'USA (INS/DHS)': 'United States'})
csv3['destination_country']=csv3['destination_country'].replace({'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom'})

date1=['2016']
df3=csv3[csv3['destination_country'].isin(my_list)]
df3=csv3[csv3['Year'].isin(date1)]

# %%
df3
# Out:
#        Year destination_country  \
# 16927  2016               Aruba
# 16928  2016         Afghanistan
# 16929  2016         Afghanistan
# 16930  2016         Afghanistan
# 16931  2016         Afghanistan
# ...     ...                 ...
# 18351  2016              Zambia
# 18352  2016              Zambia
# 18353  2016              Zambia
# 18354  2016            Zimbabwe
# 18355  2016            Zimbabwe
#
#                                        Location Name Female 0-4 Female 5-11  \
# 16927   Aruba : Dispersed in the country / territory        NaN         NaN
# 16928                   Jawzjan : Wilayat - Province       2700        3099
# 16929                     Hirat : Wilayat - Province         80          78
# 16930                     Herat : Wilayat - Province      13641       17630
# 16931                   Helmand : Wilayat - Province      19703       20036
# ...                                              ...        ...         ...
# 18351                           Mayukwayukwa : Point        983        1456
# 18352                                 Meheba : Point       1248        2364
# 18353  Zambia : Dispersed in the country / territory        637        1444
# 18354                                  Harare : City        220         117
# 18355                          Manicaland : Province        496         769
#
#       Female 5-17 Female 12-17 Female 18-59 Female 60+ F: Unknown F: Total  \
# 16927         NaN          NaN            *        NaN        NaN        *
# 16928         NaN         3008         4947        663        NaN    14417
# 16929         NaN          122          354          0        NaN      634
# 16930         NaN         9152        31920       1700        NaN    74043
# 16931         NaN        17923        47314       5654        NaN   110630
# ...           ...          ...          ...        ...        ...      ...
# 18351         NaN          934         2878        157        NaN     6408
# 18352         NaN         1598         4182        300        NaN     9692
# 18353         NaN          979         2712        400        NaN     6172
# 18354         NaN           82          296         11        NaN      726
# 18355         NaN          525         1450         58        NaN     3298
#
#       Male 0-4 Male 5-11 Male 5-17 Male 12-17 Male 18-59 Male 60+ M: Unknown  \
# 16927      NaN         *       NaN        NaN          *      NaN        NaN
# 16928     2837      2411       NaN       2752       4387      783        NaN
# 16929      136       139       NaN        210        373       58        NaN
# 16930    18943     11189       NaN      14829      27563     1675        NaN
# 16931    21366     23091       NaN      16280      46140     5110        NaN
# ...        ...       ...       ...        ...        ...      ...        ...
# 18351      982      1416       NaN        903       3202      326        NaN
# 18352     1205      2367       NaN       1693       4963      467        NaN
# 18353      602      1314       NaN       1018       2786      512        NaN
# 18354      204       115       NaN         91        432       11        NaN
# 18355      462       829       NaN        604       1688       42        NaN
#
#       M: Total
# 16927        *
# 16928    13170
# 16929      916
# 16930    74199
# 16931   111987
# ...        ...
# 18351     6829
# 18352    10695
# 18353     6232
# 18354      853
# 18355     3625
#
# [1429 rows x 19 columns]

# %%
df3=df3.drop(['Year','Female 0-4','Female 5-11','Female 5-17','Female 12-17','Female 18-59','Female 60+','F: Unknown'],axis=1)

# %%
df3=df3.drop(['Male 0-4','Male 5-11','Male 5-17','Male 12-17','Male 18-59','Male 60+','M: Unknown','Location Name'],axis=1)

# %%
df3
# Out:
#       destination_country F: Total M: Total
# 16927               Aruba        *        *
# 16928         Afghanistan    14417    13170
# 16929         Afghanistan      634      916
# 16930         Afghanistan    74043    74199
# 16931         Afghanistan   110630   111987
# ...                   ...      ...      ...
# 18351              Zambia     6408     6829
# 18352              Zambia     9692    10695
# 18353              Zambia     6172     6232
# 18354            Zimbabwe      726      853
# 18355            Zimbabwe     3298     3625
#
# [1429 rows x 3 columns]

# %%
csv6=pd.read_csv('hackATHON/time_series.csv', dtype='unicode')
csv6

# %%
csv7=pd.read_csv('hackATHON/Costofliving.csv', dtype='unicode')
csv8=pd.read_csv('hackATHON/govt.csv', dtype='unicode')
csv9=pd.read_csv('hackATHON/crimeindex.csv', dtype='unicode')
csv10=pd.read_csv('hackATHON/population.csv', dtype='unicode')

# %%
csv10
